# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("SEM_Images/R5 K3Me3 SiO2_3-3.tif)
img = np.array(img, dtype=np.uint8)

# %%
kernel = np.ones((5,5), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
canny = cv2.Canny(opening,100,150,3,L2gradient=True)
fig, ax = plt.subplots(3,1,figsize=(30,30))
ax[0].imshow(opening)
ax[1].imshow(canny)
ax[2].imshow(img)

# %%
img1 = cv2.imread('Opal_tecopa_near_gem.jpg')
img1 = np.array(img, dtype=np.uint8)

# %%
kernel1 = np.ones((5,5), np.uint8)
opening1 = cv2.morphologyEx(img1, cv2.MORPH_OPEN, kernel1)
canny1 = cv2.Canny(opening1,100,150,3,L2gradient=True)
fig, ax = plt.subplots(3,1,figsize=(30,30))
ax[0].imshow(opening1)
ax[1].imshow(canny1)
ax[2].imshow(img1)
